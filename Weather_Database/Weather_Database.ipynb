# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 715

# %%
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8b8e160125439fb51460a5b0a9d19b4b

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,     
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_description}) 
                          
                         
                                                
                                             
                         
                          
                          
                          

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | kavieng
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | hofn
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | cidreira
# Processing Record 13 of Set 1 | dawei
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | paamiut
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | port moresby
# Processing Record 18 of Set 1 | san cristobal
# Processing Record 19 of Set 1 | zyryanka
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | morondava
# Processing Record 22 of Set 1 | port-gentil
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | aripuana
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | burnie
# Processing Record 32 of Set 1 | rio gallegos
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | tadine
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | borovoy
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | ulaangom
# Processing Record 42 of Set 1 | salisbury
# Processing Record 43 of Set 1 | santa fe
# Processing Record 44 of Set 1 | ayios loukas
# City not found. Skipping...
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | souillac
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | batsfjord
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 2 | nyaunglebin
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | kasama
# Processing Record 10 of Set 2 | udachnyy
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | dombarovskiy
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | sonipat
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | garden city
# Processing Record 18 of Set 2 | port hedland
# Processing Record 19 of Set 2 | constitucion
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | lokoja
# Processing Record 25 of Set 2 | aksarka
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | punta umbria
# Processing Record 29 of Set 2 | havre
# Processing Record 30 of Set 2 | sungaipenuh
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | broome
# Processing Record 33 of Set 2 | isangel
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | kieta
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | chicama
# Processing Record 38 of Set 2 | carutapera
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | teya
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | padang
# Processing Record 45 of Set 2 | muli
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | anadyr
# Processing Record 1 of Set 3 | malanje
# Processing Record 2 of Set 3 | gizo
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | henties bay
# Processing Record 5 of Set 3 | riyadh
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | coquimbo
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | grand gaube
# Processing Record 10 of Set 3 | oudtshoorn
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | saint anthony
# Processing Record 13 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaeo
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | tera
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | morganton
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | rocky mountain house
# Processing Record 26 of Set 3 | dicabisagan
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | lerwick
# Processing Record 30 of Set 3 | kenai
# Processing Record 31 of Set 3 | namatanai
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | orlik
# Processing Record 36 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 37 of Set 3 | eydhafushi
# Processing Record 38 of Set 3 | alofi
# Processing Record 39 of Set 3 | haines junction
# Processing Record 40 of Set 3 | chapais
# Processing Record 41 of Set 3 | saint-francois
# Processing Record 42 of Set 3 | zaysan
# Processing Record 43 of Set 3 | alpena
# Processing Record 44 of Set 3 | hamilton
# Processing Record 45 of Set 3 | gurupi
# Processing Record 46 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 3 | assomada
# Processing Record 48 of Set 3 | mopipi
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 50 of Set 3 | muhororo
# Processing Record 1 of Set 4 | gouyave
# Processing Record 2 of Set 4 | caohai
# Processing Record 3 of Set 4 | chodavaram
# Processing Record 4 of Set 4 | alta floresta
# Processing Record 5 of Set 4 | smithers
# Processing Record 6 of Set 4 | gorontalo
# Processing Record 7 of Set 4 | homer
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | sao pedro da aldeia
# Processing Record 10 of Set 4 | beloha
# Processing Record 11 of Set 4 | fortuna
# Processing Record 12 of Set 4 | bulgan
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | gloversville
# Processing Record 15 of Set 4 | vardo
# Processing Record 16 of Set 4 | karratha
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | mayumba
# Processing Record 20 of Set 4 | adrar
# Processing Record 21 of Set 4 | xinzhi
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | asau
# Processing Record 24 of Set 4 | smolenka
# Processing Record 25 of Set 4 | lubumbashi
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | whitehorse
# Processing Record 28 of Set 4 | agadez
# Processing Record 29 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 4 | sault sainte marie
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | tanhacu
# Processing Record 33 of Set 4 | hambantota
# Processing Record 34 of Set 4 | bara
# Processing Record 35 of Set 4 | tessalit
# Processing Record 36 of Set 4 | sambava
# Processing Record 37 of Set 4 | marfino
# Processing Record 38 of Set 4 | kaffrine
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | olinda
# Processing Record 41 of Set 4 | pringsewu
# Processing Record 42 of Set 4 | manzhouli
# Processing Record 43 of Set 4 | barranca
# Processing Record 44 of Set 4 | half moon bay
# Processing Record 45 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 4 | columbus
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | moreira sales
# Processing Record 49 of Set 4 | valparaiso
# Processing Record 50 of Set 4 | passy
# Processing Record 1 of Set 5 | terrace
# Processing Record 2 of Set 5 | calama
# Processing Record 3 of Set 5 | charlestown
# Processing Record 4 of Set 5 | havoysund
# Processing Record 5 of Set 5 | tomatlan
# Processing Record 6 of Set 5 | zimovniki
# Processing Record 7 of Set 5 | joensuu
# Processing Record 8 of Set 5 | geraldton
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | mahebourg
# Processing Record 11 of Set 5 | port blair
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 5 | nemuro
# Processing Record 15 of Set 5 | yar-sale
# Processing Record 16 of Set 5 | yellandu
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | avera
# Processing Record 20 of Set 5 | ixcaquixtla
# City not found. Skipping...
# Processing Record 21 of Set 5 | puerto leguizamo
# Processing Record 22 of Set 5 | goderich
# Processing Record 23 of Set 5 | lindsay
# Processing Record 24 of Set 5 | vitim
# Processing Record 25 of Set 5 | francistown
# Processing Record 26 of Set 5 | arman
# Processing Record 27 of Set 5 | talcahuano
# Processing Record 28 of Set 5 | cedar city
# Processing Record 29 of Set 5 | tubinskiy
# Processing Record 30 of Set 5 | san quintin
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | waipawa
# Processing Record 33 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 5 | anloga
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | parrita
# Processing Record 38 of Set 5 | deputatskiy
# Processing Record 39 of Set 5 | lorengau
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | nyurba
# Processing Record 44 of Set 5 | denpasar
# Processing Record 45 of Set 5 | kahului
# Processing Record 46 of Set 5 | port macquarie
# Processing Record 47 of Set 5 | savonlinna
# Processing Record 48 of Set 5 | dali
# Processing Record 49 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 5 | kuningan
# Processing Record 1 of Set 6 | dubbo
# Processing Record 2 of Set 6 | ouadda
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | caravelas
# Processing Record 5 of Set 6 | byron bay
# Processing Record 6 of Set 6 | laurel
# Processing Record 7 of Set 6 | baghmara
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | luanda
# Processing Record 10 of Set 6 | harrisonburg
# Processing Record 11 of Set 6 | bandundu
# Processing Record 12 of Set 6 | zhengjiatun
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | takaka
# Processing Record 15 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 6 | kaitangata
# Processing Record 17 of Set 6 | hokitika
# Processing Record 18 of Set 6 | mount gambier
# Processing Record 19 of Set 6 | quelimane
# Processing Record 20 of Set 6 | khatanga
# Processing Record 21 of Set 6 | barcelona
# Processing Record 22 of Set 6 | bardiyah
# Processing Record 23 of Set 6 | hoquiam
# Processing Record 24 of Set 6 | schattdorf
# Processing Record 25 of Set 6 | bonthe
# Processing Record 26 of Set 6 | dukat
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | constantine
# Processing Record 29 of Set 6 | belaya gora
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | krasnoselkup
# Processing Record 32 of Set 6 | fomboni
# Processing Record 33 of Set 6 | cabedelo
# Processing Record 34 of Set 6 | majene
# Processing Record 35 of Set 6 | eldorado
# Processing Record 36 of Set 6 | baglung
# Processing Record 37 of Set 6 | suriapet
# Processing Record 38 of Set 6 | pinawa
# Processing Record 39 of Set 6 | san isidro
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | visby
# Processing Record 42 of Set 6 | sayat
# Processing Record 43 of Set 6 | lakatoro
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 6 | khonsa
# Processing Record 47 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 6 | chippewa falls
# Processing Record 49 of Set 6 | abu dhabi
# Processing Record 50 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | trairi
# Processing Record 3 of Set 7 | tasiilaq
# Processing Record 4 of Set 7 | hanmer springs
# Processing Record 5 of Set 7 | neftegorsk
# Processing Record 6 of Set 7 | pecos
# Processing Record 7 of Set 7 | laramie
# Processing Record 8 of Set 7 | ozernovskiy
# Processing Record 9 of Set 7 | kargil
# Processing Record 10 of Set 7 | pitimbu
# Processing Record 11 of Set 7 | opmeer
# Processing Record 12 of Set 7 | vostok
# Processing Record 13 of Set 7 | jumla
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | srednekolymsk
# Processing Record 16 of Set 7 | miandrivazo
# Processing Record 17 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | leopold
# Processing Record 19 of Set 7 | iqaluit
# Processing Record 20 of Set 7 | iquitos
# Processing Record 21 of Set 7 | harper
# Processing Record 22 of Set 7 | bad langensalza
# Processing Record 23 of Set 7 | huilong
# Processing Record 24 of Set 7 | ekpoma
# Processing Record 25 of Set 7 | kushmurun
# Processing Record 26 of Set 7 | saravan
# Processing Record 27 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | manta
# Processing Record 29 of Set 7 | dzhebariki-khaya
# Processing Record 30 of Set 7 | miajadas
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | semporna
# Processing Record 33 of Set 7 | saint-philippe
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | lac du bonnet
# Processing Record 36 of Set 7 | coahuayana
# Processing Record 37 of Set 7 | lata
# Processing Record 38 of Set 7 | airai
# Processing Record 39 of Set 7 | miri
# Processing Record 40 of Set 7 | fort nelson
# Processing Record 41 of Set 7 | itarema
# Processing Record 42 of Set 7 | placido de castro
# Processing Record 43 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 7 | axim
# Processing Record 45 of Set 7 | lasa
# Processing Record 46 of Set 7 | mackay
# Processing Record 47 of Set 7 | stromness
# Processing Record 48 of Set 7 | mumford
# Processing Record 49 of Set 7 | arlit
# Processing Record 50 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 8 | hami
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | baykit
# Processing Record 4 of Set 8 | acari
# Processing Record 5 of Set 8 | vanimo
# Processing Record 6 of Set 8 | wawa
# Processing Record 7 of Set 8 | pandan
# Processing Record 8 of Set 8 | lixourion
# Processing Record 9 of Set 8 | khasan
# Processing Record 10 of Set 8 | namibe
# Processing Record 11 of Set 8 | mangrol
# Processing Record 12 of Set 8 | sioux lookout
# Processing Record 13 of Set 8 | san rafael
# Processing Record 14 of Set 8 | gunjur
# Processing Record 15 of Set 8 | nalut
# Processing Record 16 of Set 8 | samarai
# Processing Record 17 of Set 8 | odweyne
# Processing Record 18 of Set 8 | willowmore
# Processing Record 19 of Set 8 | kuching
# Processing Record 20 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 22 of Set 8 | fairhope
# Processing Record 23 of Set 8 | cap malheureux
# Processing Record 24 of Set 8 | jimo
# Processing Record 25 of Set 8 | calatayud
# Processing Record 26 of Set 8 | ciudad bolivar
# Processing Record 27 of Set 8 | pueblo
# Processing Record 28 of Set 8 | ossora
# Processing Record 29 of Set 8 | kurchum
# Processing Record 30 of Set 8 | sint anthonis
# Processing Record 31 of Set 8 | price
# Processing Record 32 of Set 8 | san carlos
# Processing Record 33 of Set 8 | hastings
# Processing Record 34 of Set 8 | skrunda
# Processing Record 35 of Set 8 | tilichiki
# Processing Record 36 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 37 of Set 8 | ukiah
# Processing Record 38 of Set 8 | heihe
# Processing Record 39 of Set 8 | bitung
# Processing Record 40 of Set 8 | richards bay
# Processing Record 41 of Set 8 | buala
# Processing Record 42 of Set 8 | ostrovnoy
# Processing Record 43 of Set 8 | jalu
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | kirakira
# Processing Record 46 of Set 8 | altagracia de orituco
# Processing Record 47 of Set 8 | galle
# Processing Record 48 of Set 8 | jeremoabo
# Processing Record 49 of Set 8 | chuguyevka
# Processing Record 50 of Set 8 | lazurne
# Processing Record 1 of Set 9 | vieques
# Processing Record 2 of Set 9 | ancud
# Processing Record 3 of Set 9 | miyang
# Processing Record 4 of Set 9 | skjervoy
# Processing Record 5 of Set 9 | khrebtovaya
# Processing Record 6 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 7 of Set 9 | hohhot
# Processing Record 8 of Set 9 | juneau
# Processing Record 9 of Set 9 | elhovo
# Processing Record 10 of Set 9 | ewa beach
# Processing Record 11 of Set 9 | turka
# Processing Record 12 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 9 | charters towers
# Processing Record 14 of Set 9 | yongan
# Processing Record 15 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 9 | srandakan
# Processing Record 17 of Set 9 | turangi
# Processing Record 18 of Set 9 | dingle
# Processing Record 19 of Set 9 | muisne
# Processing Record 20 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 21 of Set 9 | baraut
# Processing Record 22 of Set 9 | bubaque
# Processing Record 23 of Set 9 | necochea
# Processing Record 24 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 9 | deniliquin
# Processing Record 26 of Set 9 | iskateley
# Processing Record 27 of Set 9 | salinopolis
# Processing Record 28 of Set 9 | tutoia
# Processing Record 29 of Set 9 | nome
# Processing Record 30 of Set 9 | alekseyevsk
# Processing Record 31 of Set 9 | touros
# Processing Record 32 of Set 9 | manado
# Processing Record 33 of Set 9 | jhajjar
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | saint george
# Processing Record 36 of Set 9 | siguiri
# Processing Record 37 of Set 9 | ilulissat
# Processing Record 38 of Set 9 | pemba
# Processing Record 39 of Set 9 | ler
# Processing Record 40 of Set 9 | ahome
# Processing Record 41 of Set 9 | balclutha
# Processing Record 42 of Set 9 | comodoro rivadavia
# Processing Record 43 of Set 9 | griffith
# Processing Record 44 of Set 9 | mayo
# Processing Record 45 of Set 9 | alugan
# Processing Record 46 of Set 9 | muzhi
# Processing Record 47 of Set 9 | lakselv
# Processing Record 48 of Set 9 | mangan
# Processing Record 49 of Set 9 | belomorsk
# Processing Record 50 of Set 9 | djibo
# Processing Record 1 of Set 10 | ghansor
# Processing Record 2 of Set 10 | mandalgovi
# Processing Record 3 of Set 10 | ise
# Processing Record 4 of Set 10 | acapulco
# Processing Record 5 of Set 10 | bintulu
# Processing Record 6 of Set 10 | aloleng
# Processing Record 7 of Set 10 | plettenberg bay
# Processing Record 8 of Set 10 | yulara
# Processing Record 9 of Set 10 | arklow
# Processing Record 10 of Set 10 | solnechnyy
# Processing Record 11 of Set 10 | lashio
# Processing Record 12 of Set 10 | nantucket
# Processing Record 13 of Set 10 | gat
# Processing Record 14 of Set 10 | ntoum
# Processing Record 15 of Set 10 | shingu
# Processing Record 16 of Set 10 | san policarpo
# Processing Record 17 of Set 10 | aksu
# Processing Record 18 of Set 10 | lazaro cardenas
# Processing Record 19 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 10 | fairbanks
# Processing Record 21 of Set 10 | iisalmi
# Processing Record 22 of Set 10 | daye
# Processing Record 23 of Set 10 | saint-augustin
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | chabahar
# Processing Record 26 of Set 10 | bemidji
# Processing Record 27 of Set 10 | mehamn
# Processing Record 28 of Set 10 | tashtyp
# Processing Record 29 of Set 10 | meadow lake
# Processing Record 30 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 10 | quirinopolis
# Processing Record 32 of Set 10 | znin
# Processing Record 33 of Set 10 | morant bay
# Processing Record 34 of Set 10 | santiago
# Processing Record 35 of Set 10 | bud
# Processing Record 36 of Set 10 | kuandian
# Processing Record 37 of Set 10 | ilfracombe
# Processing Record 38 of Set 10 | roma
# Processing Record 39 of Set 10 | mingaora
# Processing Record 40 of Set 10 | kamenka
# Processing Record 41 of Set 10 | shache
# Processing Record 42 of Set 10 | macau
# Processing Record 43 of Set 10 | shimoda
# Processing Record 44 of Set 10 | medina
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | pangai
# Processing Record 47 of Set 10 | marana
# Processing Record 48 of Set 10 | castanos
# Processing Record 49 of Set 10 | olinala
# Processing Record 50 of Set 10 | perth
# Processing Record 1 of Set 11 | vila franca do campo
# Processing Record 2 of Set 11 | dunedin
# Processing Record 3 of Set 11 | warmbad
# Processing Record 4 of Set 11 | pangnirtung
# Processing Record 5 of Set 11 | mitu
# Processing Record 6 of Set 11 | aden
# Processing Record 7 of Set 11 | tubmanburg
# Processing Record 8 of Set 11 | sisimiut
# Processing Record 9 of Set 11 | biak
# Processing Record 10 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | lewistown
# Processing Record 13 of Set 11 | qaqortoq
# Processing Record 14 of Set 11 | tahe
# Processing Record 15 of Set 11 | pokhara
# Processing Record 16 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 11 | pitea
# Processing Record 18 of Set 11 | mahajanga
# Processing Record 19 of Set 11 | jijiga
# Processing Record 20 of Set 11 | kashi
# Processing Record 21 of Set 11 | safaga
# Processing Record 22 of Set 11 | vestmannaeyjar
# Processing Record 23 of Set 11 | viedma
# Processing Record 24 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 25 of Set 11 | inhambane
# Processing Record 26 of Set 11 | sibolga
# Processing Record 27 of Set 11 | challapata
# Processing Record 28 of Set 11 | nouadhibou
# Processing Record 29 of Set 11 | bindura
# Processing Record 30 of Set 11 | pozhva
# Processing Record 31 of Set 11 | hereford
# Processing Record 32 of Set 11 | nivala
# Processing Record 33 of Set 11 | beaverlodge
# Processing Record 34 of Set 11 | nacogdoches
# Processing Record 35 of Set 11 | vallenar
# Processing Record 36 of Set 11 | natal
# Processing Record 37 of Set 11 | tacuarembo
# Processing Record 38 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | northam
# Processing Record 41 of Set 11 | fengzhen
# Processing Record 42 of Set 11 | lumeje
# Processing Record 43 of Set 11 | egvekinot
# Processing Record 44 of Set 11 | panguna
# Processing Record 45 of Set 11 | soyo
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | karlskoga
# Processing Record 48 of Set 11 | maragogi
# Processing Record 49 of Set 11 | aykhal
# Processing Record 50 of Set 11 | poltsamaa
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | gavle
# Processing Record 3 of Set 12 | ixtapa
# Processing Record 4 of Set 12 | flagstaff
# Processing Record 5 of Set 12 | amarillo
# Processing Record 6 of Set 12 | tergnier
# Processing Record 7 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 12 | znamenskoye
# Processing Record 9 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 12 | zheleznodorozhnyy
# Processing Record 11 of Set 12 | ballina
# Processing Record 12 of Set 12 | savalou
# Processing Record 13 of Set 12 | flinders
# Processing Record 14 of Set 12 | poselki
# Processing Record 15 of Set 12 | dunkirk
# Processing Record 16 of Set 12 | curitibanos
# Processing Record 17 of Set 12 | badarpur
# Processing Record 18 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 12 | anaconda
# Processing Record 20 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 21 of Set 12 | kloulklubed
# Processing Record 22 of Set 12 | rafaela
# Processing Record 23 of Set 12 | manaure
# Processing Record 24 of Set 12 | camocim
# Processing Record 25 of Set 12 | leh
# Processing Record 26 of Set 12 | tanout
# Processing Record 27 of Set 12 | nisia floresta
# Processing Record 28 of Set 12 | mildura
# Processing Record 29 of Set 12 | ust-nera
# Processing Record 30 of Set 12 | matara
# Processing Record 31 of Set 12 | atar
# Processing Record 32 of Set 12 | cervo
# Processing Record 33 of Set 12 | zalantun
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | fenoarivo
# Processing Record 36 of Set 12 | tonisvorst
# Processing Record 37 of Set 12 | sterling
# Processing Record 38 of Set 12 | belyy yar
# Processing Record 39 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 12 | porbandar
# Processing Record 41 of Set 12 | kaseda
# Processing Record 42 of Set 12 | gambiran
# Processing Record 43 of Set 12 | almenevo
# City not found. Skipping...
# Processing Record 44 of Set 12 | murgab
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 12 | cermeno
# Processing Record 48 of Set 12 | nishihara
# Processing Record 49 of Set 12 | troitsko-pechorsk
# Processing Record 50 of Set 12 | potosi
# Processing Record 1 of Set 13 | hervey bay
# Processing Record 2 of Set 13 | kyra
# Processing Record 3 of Set 13 | poum
# Processing Record 4 of Set 13 | north platte
# Processing Record 5 of Set 13 | sesheke
# Processing Record 6 of Set 13 | kosa
# Processing Record 7 of Set 13 | hingatungan
# Processing Record 8 of Set 13 | maniitsoq
# Processing Record 9 of Set 13 | kiruna
# Processing Record 10 of Set 13 | sokolo
# Processing Record 11 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 13 | maltahohe
# Processing Record 15 of Set 13 | sapa
# Processing Record 16 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 17 of Set 13 | suluktu
# Processing Record 18 of Set 13 | monteagudo
# Processing Record 19 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 13 | roald
# Processing Record 21 of Set 13 | kasongo-lunda
# Processing Record 22 of Set 13 | la palma
# Processing Record 23 of Set 13 | kabanjahe
# Processing Record 24 of Set 13 | thunder bay
# Processing Record 25 of Set 13 | aklavik
# Processing Record 26 of Set 13 | sibu
# Processing Record 27 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 13 | erdemli
# Processing Record 29 of Set 13 | pakxe
# Processing Record 30 of Set 13 | palana
# Processing Record 31 of Set 13 | florianopolis
# Processing Record 32 of Set 13 | brokopondo
# Processing Record 33 of Set 13 | champerico
# Processing Record 34 of Set 13 | hovd
# Processing Record 35 of Set 13 | madaoua
# Processing Record 36 of Set 13 | moshupa
# Processing Record 37 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 38 of Set 13 | sawtell
# Processing Record 39 of Set 13 | danjiangkou
# Processing Record 40 of Set 13 | tuy hoa
# Processing Record 41 of Set 13 | panacan
# Processing Record 42 of Set 13 | hay river
# Processing Record 43 of Set 13 | rognan
# Processing Record 44 of Set 13 | nioro
# Processing Record 45 of Set 13 | helong
# Processing Record 46 of Set 13 | brzeziny
# Processing Record 47 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 13 | kulunda
# Processing Record 49 of Set 13 | robertsport
# Processing Record 50 of Set 13 | jati
# Processing Record 1 of Set 14 | roros
# Processing Record 2 of Set 14 | yvetot
# Processing Record 3 of Set 14 | olovyannaya
# Processing Record 4 of Set 14 | el alto
# Processing Record 5 of Set 14 | katobu
# Processing Record 6 of Set 14 | jasper
# Processing Record 7 of Set 14 | vaitape
# Processing Record 8 of Set 14 | xining
# Processing Record 9 of Set 14 | jambi
# Processing Record 10 of Set 14 | syracuse
# Processing Record 11 of Set 14 | mnogovershinnyy
# Processing Record 12 of Set 14 | soeng sang
# Processing Record 13 of Set 14 | ambon
# Processing Record 14 of Set 14 | minsk
# Processing Record 15 of Set 14 | porto belo
# Processing Record 16 of Set 14 | santa vitoria do palmar
# Processing Record 17 of Set 14 | lamar
# Processing Record 18 of Set 14 | raga
# Processing Record 19 of Set 14 | weligama
# Processing Record 20 of Set 14 | dolores
# Processing Record 21 of Set 14 | yining
# Processing Record 22 of Set 14 | kondinskoye
# Processing Record 23 of Set 14 | pemangkat
# Processing Record 24 of Set 14 | smolensk
# Processing Record 25 of Set 14 | kibala
# Processing Record 26 of Set 14 | khaniotis
# Processing Record 27 of Set 14 | ilhabela
# Processing Record 28 of Set 14 | marawi
# Processing Record 29 of Set 14 | port lincoln
# Processing Record 30 of Set 14 | leshukonskoye
# Processing Record 31 of Set 14 | solwezi
# Processing Record 32 of Set 14 | dryden
# Processing Record 33 of Set 14 | taksimo
# Processing Record 34 of Set 14 | galesburg
# Processing Record 35 of Set 14 | intipuca
# Processing Record 36 of Set 14 | esmeraldas
# Processing Record 37 of Set 14 | ginda
# Processing Record 38 of Set 14 | vanavara
# Processing Record 39 of Set 14 | sol-iletsk
# Processing Record 40 of Set 14 | powell river
# Processing Record 41 of Set 14 | waddan
# Processing Record 42 of Set 14 | rocha
# Processing Record 43 of Set 14 | magistralnyy
# Processing Record 44 of Set 14 | virginia beach
# Processing Record 45 of Set 14 | los llanos de aridane
# Processing Record 46 of Set 14 | cabinda
# Processing Record 47 of Set 14 | sivaki
# Processing Record 48 of Set 14 | yichang
# Processing Record 49 of Set 14 | chara
# Processing Record 50 of Set 14 | klungkung
# Processing Record 1 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 2 of Set 15 | sarkand
# Processing Record 3 of Set 15 | balaka
# Processing Record 4 of Set 15 | trelew
# Processing Record 5 of Set 15 | ulagan
# Processing Record 6 of Set 15 | quatre cocos
# Processing Record 7 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 15 | itaqui
# Processing Record 9 of Set 15 | kadoma
# Processing Record 10 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 15 | valley station
# Processing Record 12 of Set 15 | pundaguitan
# Processing Record 13 of Set 15 | saa
# Processing Record 14 of Set 15 | xichang
# Processing Record 15 of Set 15 | aubenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus      ZA -34.4187   19.2345     55.90        75           0
# 1  Tuktoyaktuk      CA  69.4541 -133.0374     23.00       100          90
# 2        Vaini      TO -21.2000 -175.2000     74.21        66          54
# 3       Hobart      AU -42.8794  147.3294     52.27        60          75
# 4      Kavieng      PG  -2.5744  150.7967     86.07        66          58
#
#    Wind Speed Current description
# 0       10.56           clear sky
# 1       11.50                mist
# 2       17.83       broken clouds
# 3        1.01          light rain
# 4       14.99       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
